# %%
#imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Read in our data
df = pd.read_csv('s5092_NO2_calibration.csv')
df
# Out:
#                   dt_time      no2op1      no2op2  humidity_vaisala  \
# 0     2023-04-01 12:30:00  229.400000  224.333333         46.733333
# 1     2023-04-01 12:45:00  228.000000  224.266667         45.700000
# 2     2023-04-01 13:00:00  225.666667  223.866667         42.400000
# 3     2023-04-01 13:45:00  225.333333  222.533333         44.100000
# 4     2023-04-01 14:00:00  223.800000  221.933333         43.800000
# ...                   ...         ...         ...               ...
# 2922  2023-05-02 23:00:00  245.600000  229.066667         72.700000
# 2923  2023-05-02 23:15:00  245.466667  229.000000         73.033333
# 2924  2023-05-02 23:30:00  244.600000  228.933333         74.933333
# 2925  2023-05-02 23:45:00  246.133333  228.933333         77.333333
# 2926  2023-05-03 00:00:00  245.266667  229.000000         76.200000
#
#       temp_vaisala    NO2
# 0        29.833333  7.362
# 1        29.633333  7.242
# 2        31.066667  6.801
# 3        29.833333  6.523
# 4        30.100000  5.961
# ...            ...    ...
# 2922     25.033333  5.721
# 2923     24.733333  4.170
# 2924     24.400000  3.499
# 2925     23.933333  3.513
# 2926     23.900000  3.675
#
# [2927 rows x 6 columns]

# %%
#set dt_time as index
df['dt_time'] = pd.to_datetime(df['dt_time'])
df.set_index(df['dt_time'])
# Out:
#                                 dt_time      no2op1      no2op2  \
# dt_time
# 2023-04-01 12:30:00 2023-04-01 12:30:00  229.400000  224.333333
# 2023-04-01 12:45:00 2023-04-01 12:45:00  228.000000  224.266667
# 2023-04-01 13:00:00 2023-04-01 13:00:00  225.666667  223.866667
# 2023-04-01 13:45:00 2023-04-01 13:45:00  225.333333  222.533333
# 2023-04-01 14:00:00 2023-04-01 14:00:00  223.800000  221.933333
# ...                                 ...         ...         ...
# 2023-05-02 23:00:00 2023-05-02 23:00:00  245.600000  229.066667
# 2023-05-02 23:15:00 2023-05-02 23:15:00  245.466667  229.000000
# 2023-05-02 23:30:00 2023-05-02 23:30:00  244.600000  228.933333
# 2023-05-02 23:45:00 2023-05-02 23:45:00  246.133333  228.933333
# 2023-05-03 00:00:00 2023-05-03 00:00:00  245.266667  229.000000
#
#                      humidity_vaisala  temp_vaisala    NO2
# dt_time
# 2023-04-01 12:30:00         46.733333     29.833333  7.362
# 2023-04-01 12:45:00         45.700000     29.633333  7.242
# 2023-04-01 13:00:00         42.400000     31.066667  6.801
# 2023-04-01 13:45:00         44.100000     29.833333  6.523
# 2023-04-01 14:00:00         43.800000     30.100000  5.961
# ...                               ...           ...    ...
# 2023-05-02 23:00:00         72.700000     25.033333  5.721
# 2023-05-02 23:15:00         73.033333     24.733333  4.170
# 2023-05-02 23:30:00         74.933333     24.400000  3.499
# 2023-05-02 23:45:00         77.333333     23.933333  3.513
# 2023-05-03 00:00:00         76.200000     23.900000  3.675
#
# [2927 rows x 6 columns]

# %%
#Splitting our data (70-30)
training_data = df[df['dt_time'].between("2023-04-01 12:30:00","2023-04-22 21:00:00")]
testing_data = df[df["dt_time"].between("2023-04-22 21:15:00", "2023-05-04")]
X_train = training_data.drop(["dt_time", "NO2"], axis=1)
X_test = testing_data.drop(['dt_time', "NO2"], axis=1)
y_train = training_data['NO2']
y_test = testing_data['NO2']

# %%
#Applying Ridge Regression on training data
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha = 50, max_iter = 100, tol = 0.1)
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
#making predictions
y_pred_train = ridge_reg.predict(X_train)

# %%
#Visualising our data
plt.scatter(y_train, y_pred_train, label = 'Training Data', color = 'r')
plt.xlabel('Ground Truth NO2')
plt.ylabel('Predicted NO2')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Time-Series Plot
fig, ax = plt.subplots()
ax.plot(training_data['dt_time'], y_train, label = 'Ground Truth Values', color = 'r')
ax.set_xlabel('Time')
ax.set_ylabel('Ground Truth NO2')
ax1 = ax.twinx()
ax1.plot(training_data['dt_time'], y_pred_train, label = "Predicted Values", color = 'b')
ax1.set_xlabel("Time")
ax1.set_ylabel("Predicted NO2")
fig.legend()
plt.show()

# %%
#imoorting r2_score
from sklearn.metrics import r2_score
print(f'r2 score from training data: {r2_score(y_train, y_pred_train)}')
# Out:
# r2 score from training data: 0.2585662935900538

# %%
#Testing Data
ridge_reg.fit(X_test, y_test)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
#Making predictions 
y_pred_test = ridge_reg.predict(X_test)

# %%
plt.scatter(y_test, y_pred_test, label = 'Testing Data', color = 'r')
plt.xlabel('Ground Truth NO2')
plt.ylabel('Predicted NO2')
plt.show()

# %%
print(f'r2 score from testing data: {r2_score(y_test, y_pred_test)}')
# Out:
# r2 score from testing data: 0.19092690018418834

# %%
#Time Series plot
fig1,ax2 = plt.subplots()
ax2.plot(testing_data['dt_time'], y_test, label = 'Ground Truth Values', color = 'r')
ax2.set_xlabel("Time")
ax2.set_ylabel("Ground Truth NO2")
ax3 = ax2.twinx()
ax3.plot(testing_data['dt_time'], y_pred_test, label = 'Predicted values', color = 'b')
ax3.set_xlabel('Time')
ax3.set_ylabel("Predicted NO2")
fig.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
