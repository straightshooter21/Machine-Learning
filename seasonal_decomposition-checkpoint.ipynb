# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv('/home/nihal/mtech thesis/src/clean_data/analyzer_data_feb_to_may_end.csv')
df['dt_time'] = pd.to_datetime(df['dt_time'])

# %%
df.head()
# Out:
#               dt_time      CO    SO2     O3  NO2
# 0 2023-02-01 00:15:00  1318.0  3.779  29.33  NaN
# 1 2023-02-01 00:30:00  1315.0  3.724  28.81  NaN
# 2 2023-02-01 00:45:00  1320.0  3.739  28.60  NaN
# 3 2023-02-01 01:00:00  1321.0  3.692  28.62  NaN
# 4 2023-02-01 01:15:00  1318.0  3.836  28.53  NaN

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = make_subplots()

# Add traces
fig.add_trace(
    go.Scatter(x=df['dt_time'], y=df['CO'])
)
fig.show(renderer='browser')

# %%
df_mar = df.loc[(df['dt_time']>=pd.to_datetime('2023-03-09 00:15:00')) & (df['dt_time']<=pd.to_datetime('2023-03-28 00:15:00')), :]

# %%
df_may = df.loc[(df['dt_time']>=pd.to_datetime('2023-05-05 00:15:00')) & (df['dt_time']<=pd.to_datetime('2023-05-20 00:15:00')), :]

# %%
# Perform seasonal decomposition
result = seasonal_decompose(df_mar['CO'].to_numpy(), model='additive', period=24*4)  # Period of 12 for monthly data
result.plot()
plt.show()

# %%
# Perform seasonal decomposition
result = seasonal_decompose(df_may['CO'].to_numpy(), model='additive', period=24*4)  # Period of 12 for monthly data
result.plot()
plt.show()
