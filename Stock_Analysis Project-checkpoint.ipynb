# %%
import numpy as np
import pandas as pd
import yfinance as yf
from datetime import datetime

# %%
start_date  = datetime.now() - pd.DateOffset(months = 3)
end_date = datetime.now()
tickers = ['AAPL', 'MSFT', 'NFLX', 'GOOG']
df_list = []

# %%
ticker = input("Choose Stock (By Stock Name)")
for ticker in tickers:
    data = yf.download(ticker, start = start_date, end = end_date)
    df_list.append(data)

    df = pd.concat(df_list, keys = tickers, names = ["Ticker", "Date"])
# Out:
# Choose Stock (By Stock Name)GOOG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
def" plot_data(dataframe):
# Out:
#   Cell In[14], line 1
#     def" plot_data(dataframe):
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
import plotly.express as px
fig = px.line(, x = 'Date',
              y = 'Close',
              color = 'Ticker',
            title = "Stock Marker Performance( Past 3 Months)")
fig.show()
# Out:
# <div>                            <div id="44e8bfbf-8f4f-423e-9cd5-c8e02c1a3f5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44e8bfbf-8f4f-423e-9cd5-c8e02c1a3f5a")) {                    Plotly.newPlot(                        "44e8bfbf-8f4f-423e-9cd5-c8e02c1a3f5a",                        [{"hovertemplate":"Ticker=AAPL\u003cbr\u003eDate=%{x}\u003cbr\u003eClose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AAPL","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"AAPL","orientation":"v","showlegend":true,"x":["2023-04-06T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-04-19
# ...

# %% [markdown]
# Faceted Area Chart to compare performance and identify similarities or differences in movemont

# %%
fig = px.area(df, x ="Date", y = 'Close', color = 'Ticker',
             facet_col = 'Ticker',
             labels = {'Date':'Date', 'Close': 'Closing Price', 'Ticker': 'Company'},
              title='Stock Prices for Apple, Microsoft, Netflix, and Google')
fig.show()
# Out:
# <div>                            <div id="99c22c4a-a691-4e0c-9e91-9c39ddbdc295" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99c22c4a-a691-4e0c-9e91-9c39ddbdc295")) {                    Plotly.newPlot(                        "99c22c4a-a691-4e0c-9e91-9c39ddbdc295",                        [{"fillpattern":{"shape":""},"hovertemplate":"Company=AAPL\u003cbr\u003eDate=%{x}\u003cbr\u003eClosing Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AAPL","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"AAPL","orientation":"v","showlegend":true,"stackgroup":"1","x":["2023-04-06T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-17T00:00
# ...

# %% [markdown]
# Now let’s analyze moving averages, which provide a useful way to identify trends and patterns in each company’s stock price movements over a period of time:

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
df["MA10"] = df.groupby('Ticker')['Close'].rolling(window = 20).mean().reset_index(0, drop = True)
df["MA20"] = df.groupby('Ticker')['Close'].rolling(window = 20).mean().reset_index(0, drop = True)

for ticker, group in df.groupby('Ticker'):
    print(f'Moving Averages for {ticker}')
    print(group[['MA10', 'MA20']])
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Moving Averages for AAPL
#           MA10        MA20
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# ..         ...         ...
# 56  183.182000  183.182000
# 57  183.799000  183.799000
# 58  184.493000  184.493000
# 59  185.068501  185.068501
# 60  185.656001  185.656001
#
# ...

# %% [markdown]
# Visualizing moving average of companies

# %%
for ticker, group in df.groupby('Ticker'):
    fig = px.line(group, x='Date',y=['Close', 'MA10', 'MA20'], 
                 title = f"{ticker} Moving Averages")
    fig.show()
# Out:
# <div>                            <div id="2f6e5182-f0d1-4cba-9b6d-dbea657243b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f6e5182-f0d1-4cba-9b6d-dbea657243b2")) {                    Plotly.newPlot(                        "2f6e5182-f0d1-4cba-9b6d-dbea657243b2",                        [{"hovertemplate":"variable=Close\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Close","orientation":"v","showlegend":true,"x":["2023-04-06T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-
# ...

# %% [markdown]
# The output shows four separate graphs for each company. When the MA10 crosses above the MA20, it is considered a bullish signal indicating that the stock price will continue to rise. Conversely, when the MA10 crosses below the MA20, it is a bearish signal that the stock price will continue falling

# %% [markdown]
# Let us now analyze the volatility of all companies. Volatility is a measure of how much and how often the stock price or market fluctuates over a given period of time. Here’s how to visualize the volatility of all companies:

# %%
df['Volatility'] = df.groupby('Ticker')['Close'].pct_change()
fig = px.line(df, x = 'Date', y = 'Volatility',
             color = 'Ticker', title = 'Volatility')
fig.show()
# Out:
# <div>                            <div id="8e4d0d6a-9c62-4995-b023-cfa4e9f9aaa9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e4d0d6a-9c62-4995-b023-cfa4e9f9aaa9")) {                    Plotly.newPlot(                        "8e4d0d6a-9c62-4995-b023-cfa4e9f9aaa9",                        [{"hovertemplate":"Ticker=AAPL\u003cbr\u003eDate=%{x}\u003cbr\u003eVolatility=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AAPL","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"AAPL","orientation":"v","showlegend":true,"x":["2023-04-06T00:00:00","2023-04-10T00:00:00","2023-04-11T00:00:00","2023-04-12T00:00:00","2023-04-13T00:00:00","2023-04-14T00:00:00","2023-04-17T00:00:00","2023-04-18T00:00:00","2023-
# ...

# %% [markdown]
# High volatility indicates that the stock or market experiences large and frequent price movements, while low volatility indicates that the market experiences smaller or less frequent price movements.
#
# Now let’s analyze the correlation between the stock prices of Apple and Microsoft:

# %%
apple = df.loc[df['Ticker'] == 'AAPL', ['Date', 'Close']].rename(columns={'Close': 'AAPL'})
microsoft = df.loc[df['Ticker'] == 'MSFT', ['Date', 'Close']].rename(columns={'Close': 'MSFT'})
df_corr = pd.merge(apple, microsoft, on='Date')

# create a scatter plot to visualize the correlation
fig = px.scatter(df_corr, x='AAPL', y='MSFT', 
                 trendline='ols', 
                 title='Correlation between Apple and Microsoft')
fig.show()
# Out:
# <div>                            <div id="b276d68a-436a-40b5-8295-1e7df46f69b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b276d68a-436a-40b5-8295-1e7df46f69b7")) {                    Plotly.newPlot(                        "b276d68a-436a-40b5-8295-1e7df46f69b7",                        [{"hovertemplate":"AAPL=%{x}\u003cbr\u003eMSFT=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[164.66000366210938,162.02999877929688,160.8000030517578,160.10000610351562,165.55999755859375,165.2100067138672,165.22999572753906,166.47000122070312,167.6300048828125,166.64999389648438,165.02000427246094,165.3300018310547,163.77000427246094
# ...

# %% [markdown]
# There is a strong linear relationship between the stock prices of Apple and Microsoft, which means that when the stock price of Apple increases, the stock price of Microsoft also tends to increase. It is a sign of a strong correlation or similarity between the two companies, which can be due to factors such as industry trends, market conditions, or common business partners or customers. For investors, this positive correlation may indicate an opportunity to diversify their portfolio by investing in both companies, as both stocks may offer similar potential returns and risks.
#
# So this is how you can perform stock market analysis using Python.
#
# Summary
# Stock Market Performance Analysis involves calculating moving averages, measuring volatility, conducting correlation analysis and analyzing various aspects of the stock market to gain a deeper understanding of the factors that affect stock prices and the relationships between the stock prices of different companies. I hope you liked this article on Stock Market Performance Analysis using Python. Feel free to ask valuable questions in the comments section below.
