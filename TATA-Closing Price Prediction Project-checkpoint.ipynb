# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20, 10
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense

from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("NSE-Tata-Global-Beverages-Limited.csv")
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-10-08  208.00  222.25  206.85  216.00  215.15
# 1     2018-10-05  217.00  218.60  205.90  210.25  209.20
# 2     2018-10-04  223.50  227.80  216.15  217.25  218.20
# 3     2018-10-03  230.00  237.50  225.75  226.45  227.60
# 4     2018-10-01  234.55  234.60  221.05  230.30  230.90
# ...          ...     ...     ...     ...     ...     ...
# 1230  2013-10-14  160.85  161.45  157.70  159.30  159.45
# 1231  2013-10-11  161.15  163.45  159.00  159.80  160.05
# 1232  2013-10-10  156.00  160.80  155.85  160.30  160.15
# 1233  2013-10-09  155.70  158.20  154.15  155.30  155.55
# 1234  2013-10-08  157.00  157.80  155.20  155.80  155.80
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                4642146.0         10062.83
# 1                3519515.0          7407.06
# 2                1728786.0          3815.79
# 3                1708590.0          3960.27
# 4                1534749.0          3486.05
# ...

# %%
df["Date"]=pd.to_datetime(df.Date,format="%Y-%m-%d")
df.index=df['Date']
import plotly.express as px
px.line(df, x = 'Date', y = 'Close', title = 'TATA Close Price vs Time')
# Out:
# <div>                            <div id="24627297-da24-4c30-9e47-646b8fba1b77" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24627297-da24-4c30-9e47-646b8fba1b77")) {                    Plotly.newPlot(                        "24627297-da24-4c30-9e47-646b8fba1b77",                        [{"hovertemplate":"Date=%{x}\u003cbr\u003eClose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2018-10-08T00:00:00","2018-10-05T00:00:00","2018-10-04T00:00:00","2018-10-03T00:00:00","2018-10-01T00:00:00","2018-09-28T00:00:00","2018-09-27T00:00:00","2018-09-26T00:00:00","2018-09-25T00:00:00","2018-09-24T00:00:00","2018-09-21T00:00
# ...

# %%
data=df.sort_index(ascending=True,axis=0)
new_dataset=pd.DataFrame(index=range(0,len(df)),columns=['Date','Close'])
for i in range(0,len(data)):
    new_dataset["Date"][i]=data['Date'][i]
    new_dataset["Close"][i]=data["Close"][i]

# %%
def scaledataset(dataframe):
    training_set = dataframe[:865]
    testing_set = dataframe[865:]
    
    X_train = training_set.drop(["Date", "Close"], axis = 1)
    X_test = testing_set.drop(["Date", "Close"], axis = 1)
    
    y_train = training_set["Close"]
    y_test = testing_set["Close"]
    
    return X_train, y_train, X_test, y_test

# %%
#Building the model

# %%
X_train,y_train, X_test, y_test = scaledataset(new_dataset)

lstm_model=Sequential()
lstm_model.add(LSTM(units=50,return_sequences=True,input_shape=(x_train_data.shape[1],1)))
lstm_model.add(LSTM(units=50))
lstm_model.add(Dense(1))
inputs_data=new_dataset[len(new_dataset)-len(valid_data)-60:].values
inputs_data=inputs_data.reshape(-1,1)
inputs_data=scaler.transform(inputs_data)
lstm_model.compile(loss='mean_squared_error',optimizer='adam')
lstm_model.fit(x_train_data,y_train_data,epochs=1,batch_size=1,verbose=2
# Out:
#   Cell In[101], line 10
#     lstm_model.fit(x_train_data,y_train_data,epochs=1,batch_size=1,verbose=2
#                                                                             ^
# SyntaxError: incomplete input
